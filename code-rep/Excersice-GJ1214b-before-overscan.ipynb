# %%
from astropy.io import fits
from matplotlib import pyplot as plt
import numpy as np
from convenience_functions import show_image
from ccdproc import ImageFileCollection
import ccdproc as ccdp
from pathlib import Path

# %%
# Looking at the header for one set of data:
#hdu_list = fits.open('/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R001.fits')
#hdu = hdu_list[0]
#hdu.header

# %%
# Looking at the headers of all files in one directory collectively
data_directory = '/Users/applestore/exo-observe/Data/GJ-1214b/raw_data'

image_path = Path(data_directory)

image_path.mkdir(parents=True, exist_ok=True)

im = ccdp.ImageFileCollection(data_directory)
science= im.summary
science['obstype', 'exptime','darktime','date-obs', 'crval1', 'crval2']

# Method 2 just to get a list of file names.
#dark_files = im.summary[im.summary['obstype'] == 'DARK']['file']
#print (dark_files)
# Out:
# <Table length=351>
# obstype exptime darktime         date-obs        crval1 crval2
#   str6  float64 float64           str23          object object
# ------- ------- -------- ----------------------- ------ ------
#    DARK     5.0      5.0 2012-08-27T12:06:47.600     --     --
#    DARK     5.0      5.0 2012-08-27T12:06:35.900     --     --
#    DARK     5.0      5.0 2014-05-14T10:38:31.400     --     --
#    DARK     5.0      5.0 2012-11-07T09:44:38.400     --     --
#    DARK     5.0      5.0 2014-05-14T10:38:07.800     --     --
#    DARK     5.0      5.0 2012-08-27T12:07:23.000     --     --
#    DARK     5.0      5.0 2010-12-12T21:22:47.200     --     --
#    DARK     5.0      5.0 2015-09-05T07:00:09.800     --     --
#    DARK     5.0      5.0 2012-11-07T09:43:05.000     --     --
#    DARK     5.0      5.0 2015-09-05T07:01:08.400     --     --
#    DARK     5.0      5.0 2015-09-05T07:00:33.000     --     --
#    DARK     5.0      5.0 2010-12-12T21:22:58.800     --     --
#    DARK     5.0      5.0 2010-12-12T21:21:37.600     --     --
#    DARK     5.0      5.0 2012-11-07T09:44:03.300     --     --
#     ...     ...      ...                     ...    ...    ...
#  OBJECT     3.0      3.0 2010-04-29T08:06:30.700   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:59:06.700   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:32:26.100   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T06:39:57.300   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T08:19:44.900   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T08:59:43.500   1050   1810
#  OBJECT     5.0      5.0 2010-04-29T04:48:03.500   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:18:20.500   1050   1810
#  OBJECT    10.0     10.0 2010-04-29T04:29:06.500   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:44:16.700   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:14:22.700   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:40:10.300   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T08:28:48.500   1050   1810
#  OBJECT    10.0     10.0 2010-04-29T04:27:25.500   1050   1810
#  OBJECT     3.0      3.0 2010-04-29T07:54:58.700   1050   1810

# %%
# I don't have access to the bias files of this data set so I am trying to build one on my
# own. But the first necessary step in doing that is to find the exact size of the fits files so that
# after I construct the biases there ain't no problem reducing it from the object frames. So:

# Finding the Size of the fit's array

data=fits.getdata("/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R270.fits")

print(data.shape)
# Out:
# (2048, 568)

# %%
# I run this step to see the min and max pixel values of my image in the gray-color bar below
# Then I enter those two values in the next code block as vmin and vmax when plotting so that
# I get as much data visible on color plots as I can. Other wise the image would be all yellow or all blue (loosing)
# many data points.
data=fits.getdata("/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R270.fits")
show_image(data, cmap='gray')

# %%
# This bit show the fits image in different orientations

#import matplotlib.pyplot as plt

f,axs=plt.subplots(1,2,figsize=(16,8))
axs[0].imshow(data,vmin=3600,vmax=3800,origin='lower')
axs[0].set_title("north down, east left")
axs[1].imshow(np.flipud(data),vmin=3600,vmax=3800,origin='lower')
axs[1].set_title("north up, east left")
# Out:
# Text(0.5, 1.0, 'north up, east left')

# %%
# Creating Fake Bias frames:
import os
synthetic_image = np.zeros([2048, 563])
def read_noise(image, amount, gain=1):
    """
    Generate simulated read noise.
    
    Parameters
    ----------
    
    image: numpy array
        Image whose shape the noise array should match.
    amount : float
        Amount of read noise, in electrons.
    gain : float, optional
        Gain of the camera, in units of electrons/ADU.
    """
    shape = image.shape
    
    noise = noise_rng.normal(scale=amount/gain, size=shape)
    
    return noise

def bias(image, value, realistic=False):
    """
    Generate simulated bias image.
    
    Parameters
    ----------
    
    image: numpy array
        Image whose shape the bias array should match.
    value: float
        Bias level to add.
    realistic : bool, optional
        If ``True``, add some columns with somewhat higher bias value (a not uncommon thing)
    """
    # This is the whole thing: the bias is really suppose to be a constant offset!
    bias_im = np.zeros_like(image) + value
    
    # If we want a more realistic bias we need to do a little more work. 
    if realistic:
        shape = image.shape
        number_of_colums = 5
        
        # We want a random-looking variation in the bias, but unlike the readnoise the bias should 
        # *not* change from image to image, so we make sure to always generate the same "random" numbers.
        rng = np.random.RandomState(seed=8392)  # 20180520
        columns = rng.randint(0, shape[1], size=number_of_colums)
        # This adds a little random-looking noise into the data.
        col_pattern = rng.randint(0, int(0.1 * value), size=shape[0])
        
        # Make the chosen columns a little brighter than the rest...
        for c in columns:
            bias_im[:, c] = value + col_pattern
            
    return bias_im
        

# Set up the random number generator, allowing a seed to be set from the environment
seed = os.getenv('GUIDE_RANDOM_SEED', None)

if seed is not None:
    seed = int(seed)
    
# This is the generator to use for any image component which changes in each image, e.g. read noise
# or Poisson error
noise_rng = np.random.default_rng(seed)

plt.figure()
noise_im = synthetic_image + read_noise(synthetic_image, 5)
bias_only = bias(synthetic_image, 10, realistic=True)
bias_noise_im = noise_im + bias_only
#show_image(bias_noise_im, cmap='gray', figsize=(10, 10))
#plt.title('Realistic bias frame (includes read noise)', fontsize='20')

# %%
# If I have real bias files I will go through with this step. But as I have built one here
# myself I see no reason making more and then a master bias out of them. So insted I will pass this
# one single File that I have for now as the superbias file in the following code and this should definitely change later.
superbias = bias_noise_im
print(superbias.shape)
# combining bias frame to get a Master-bias:

 ## let's fist check the bias image
#import glob
#bfiles=glob.glob("/Users/applestore/exo-observe/Data/HAT-32b/raw_data/d*BIASR*.fit")
#bfiles.sort()
#allbias=[]
#print("combining bias ...")
#for i,ifile in enumerate(bfiles):
# print("reading bias:", i+1,len(bfiles),ifile)
# data=fits.getdata(ifile)
# allbias.append(data)
#allbias=np.stack(allbias)
#print(allbias.shape)
#superbias=np.median(allbias,axis=0)
fits.writeto('/Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/bias.fit',superbias.astype('float32'),overwrite=True)
# Out:
# (2048, 563)

# %%
## display the Master bias
plt.figure(figsize=(8,8))
plt.imshow(superbias,vmin=-5,vmax=25,origin='lower')
plt.colorbar()
plt.title("Master bias drived from bias frames")
# Out:
# Text(0.5, 1.0, 'Master bias drived from bias frames')

# %%
#dark_files = files.summary[files.summary['obstype'] == 'DARK']['file']
#print (dark_files)

# %%
# combining dome flats (with bias correction)
import glob
ffiles=glob.glob("/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d*FLATR*.fits")
ffiles.sort()
allflat=[]
print("combining dome flats...")
for i,ifile in enumerate(ffiles):
 print("reading flat:", i+1,len(ffiles),ifile)
 # flat-fielding: subtract bias and then normalize the flat images
 data=fits.getdata(ifile)
# data=fits.getdata(ifile)-superbias
 mflat=np.median(data[1500-256:1500+256,1500-256:1500+256])
# data/=mflat
 print("median flat:",mflat)
 allflat.append(data)
allflat=np.stack(allflat)
print(allflat.shape)
domeflat=np.median(allflat,axis=0)
print(domeflat.shape)

fits.writeto('/Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/domeflat.fits',domeflat.astype('float32'),overwrite=True)
# Out:
# combining dome flats...
# reading flat: 1 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR001.fits
# median flat: nan
# reading flat: 2 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR002.fits
# median flat: nan
# reading flat: 3 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR003.fits
# median flat: nan
# reading flat: 4 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR004.fits
# median flat: nan
# reading flat: 5 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR005.fits
# median flat: nan
# reading flat: 6 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR006.fits
# median flat: nan
# reading flat: 7 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR007.fits
# median flat: nan
# reading flat: 8 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR008.fits
# median flat: nan
# reading flat: 9 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR009.fits
# median flat: nan
# reading flat: 10 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR010.fits
# median flat: nan
# reading flat: 11 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR011.fits
# median flat: nan
# reading flat: 12 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR012.fits
# median flat: nan
# reading flat: 13 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR013.fits
# median flat: nan
# reading flat: 14 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR014.fits
# median flat: nan
# reading flat: 15 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR015.fits
# median flat: nan
# reading flat: 16 16 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR016.fits
# median flat: nan
# (16, 2048, 563)
# (2048, 563)

# %%
## display the Master flat
plt.figure(figsize=(8,8))
plt.imshow(domeflat,vmin=17000,vmax=21000,origin='lower')
plt.colorbar()
plt.title("Master Flat drived from flat frames")
# Out:
# Text(0.5, 1.0, 'Master Flat drived from flat frames')

# %%
# Since I don't have real bias for this: I am using the fake bias file I built twice.
# We can calculate gain and readout noise from pairs of bias and flats
# The algorithm come from the IRAF FINDGAIN program, please refer to its help information

## calculate gain and read noise
from astropy.stats import sigma_clipped_stats
biasfile1='/Users/applestore/exo-observe/Data/HAT-32b/raw_data/d4466637BIASR213.fit'
biasfile2='/Users/applestore/exo-observe/Data/HAT-32b/raw_data/d4466637BIASR214.fit'
#flatfile1='/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR016.fits'
#flatfile2='/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-FLATR012.fits'
flatfile1='/Users/applestore/exo-observe/Data/HAT-32b/raw_data/d4466637FLATR201.fit'
flatfile2='/Users/applestore/exo-observe/Data/HAT-32b/raw_data/d4466637FLATR202.fit'


bias1=fits.getdata(biasfile1)[1500-256:1500+256,1500-256:1500+256]
bias2=fits.getdata(biasfile2)[1500-256:1500+256,1500-256:1500+256]

# These lines work for the dimensions of the GJ-1214b data files. But since I don't have real bias, the resulting gain
# and readout noise because meaninglessly small. So although I have learnt the process but just for now I switch back
# to using HAT-32b data
flat1 = fits.getdata(flatfile1)[1500-256:1500+256,1500-256:1500+256]
flat2=fits.getdata(flatfile2)[1500-256:1500+256,1500-256:1500+256]

mean_flat1=np.median(flat1)
mean_flat2=np.median(flat2)
mean_bias1=np.median(bias1)
mean_bias2=np.median(bias2)
_,_,std_biasdiff=sigma_clipped_stats(bias1-bias2,sigma=4.0,maxiters=2)
_,_,std_flatdiff=sigma_clipped_stats(flat1-flat2,sigma=4.0,maxiters=2)
print(mean_bias1,mean_bias2,mean_flat1,mean_flat2,std_biasdiff,std_flatdiff)
gain=((mean_flat1+mean_flat2)-(mean_bias1+mean_bias2))/((std_flatdiff**2-std_biasdiff**2))
rdnoise=gain*std_biasdiff/np.sqrt(2)
print("gain: ",gain, "readout noise:",rdnoise)
# Out:
# WARNING: Unexpected bytes trailing END keyword: '                            / END OF HEADER'; these bytes will be replaced with spaces on write. [astropy.io.fits.header]
# WARNING:astropy:Unexpected bytes trailing END keyword: '                            / END OF HEADER'; these bytes will be replaced with spaces on write.
# WARNING: File may have been truncated: actual file length (33560192) is smaller than the expected size (33560640) [astropy.io.fits.file]
# WARNING:astropy:File may have been truncated: actual file length (33560192) is smaller than the expected size (33560640)
# 0.0 0.0 8986.0 9160.0 2.905397 72.79242
# gain:  3.430054470497312 readout noise: 7.046792664146595

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u
import glob,os
c=SkyCoord("17:25:33.46","+4:37:25.57",frame='icrs',unit=(u.hourangle,u.degree))
ra=c.ra.degree; dec=c.dec.degree
print("ra:", ra, "dec:",c.dec.degree)
epoch=2000.0
pixscale=0.137 # in arcsec
# add keywords to FITS header of science frames
outdir="/Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/"
sfiles=glob.glob("/Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d*UW32R*.fits") # science frames
sfiles.sort() # in alphabetic order
for i,ifile in enumerate(sfiles):
 print("reducing (debias, flat-fielding, and flipping) :", i+1,len(sfiles),ifile)
 indir,infile=os.path.split(ifile)
 rootname,_=os.path.splitext(infile)
 # we change the first character from "d" to "p" for new files and ensure not to cover the raw data
 outfile=os.path.join(outdir,"p"+rootname[1:]+'.fits')
 head=fits.getheader(ifile,output_verifystr="silentfix")
 # get the origin of the subregion
 col_origin=head['CRVAL1']
 row_origin=head['CRVAL2']
 
 # I have chosen not to use subflat and sub bias for now but rather use all of it:
    
 #subflat=domeflat[row_origin:row_origin+512,col_origin:col_origin+512]
 #subbias=superbias[row_origin:row_origin+512,col_origin:col_origin+512]
 #subflat = domeflat[100:100+512, 200:200+512]
 #subbias = superbias[100:100+512, 200:200+512]
 #if i==0:
 ## to show an example of the subsection of bias and flat
 #    fits.writeto('/Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/subflat.fits',subflat.astype('float32'),overwrite=True)
 #    fits.writeto('/Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/subbias.fits',subbias.astype('float32'),overwrite=True)
 #break
 data=fits.getdata(ifile)

 # de-bias and flat-fielding
# data = data[100:100+512, 200:200+507]
# data = data[:, :363]
# data=(data-subbias)/subflat

 # I have chosen not to use subflat and sub bias for now but rather use all of it:

 data = data[:, :563]
 data=(data-superbias)/domeflat

# set the initial reference point in the WCS parameters if doing astrometry
head['epoch']=2000.0


 # set the initial reference point in the WCS parameters if doing astrometry
head['epoch']=2000.0
head['CRVAL1']=ra
head['CRVAL2']=dec
# head['CRPIX1']=head['NAXIS1']/2.0
# head['CRPIX2']=head['NAXIS2']/2.0
head['CDELT1']=-pixscale/3600.0 # minus for left east
head['CDELT2']=pixscale/3600.0
head['CTYPE1']='RA---TAN' # projection type
head['CTYPE2']='DEC--TAN'
head['GAIN']=(gain,'GAIN in e-/ADU')
head['RDNOISE']=(rdnoise,'readout noise in electron')
print("writing to "+outfile)
 # flip up down to make the image with north up and east left
fits.writeto(outfile,np.flipud(data),header=head,overwrite=True,output_verify="silentfix")
# Out:
# ra: 261.38941666666665 dec: 4.623769444444445
# reducing (debias, flat-fielding, and flipping) : 1 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R001.fits
# reducing (debias, flat-fielding, and flipping) : 2 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R002.fits
# reducing (debias, flat-fielding, and flipping) : 3 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R003.fits
# reducing (debias, flat-fielding, and flipping) : 4 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R004.fits
# reducing (debias, flat-fielding, and flipping) : 5 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R005.fits
# /var/folders/kb/x7gy6w9569jgnxt7cz_dpm1m0000gn/T/ipykernel_5102/4153615126.py:39: RuntimeWarning: divide by zero encountered in divide
#   data=(data-superbias)/domeflat
# reducing (debias, flat-fielding, and flipping) : 6 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R006.fits
# reducing (debias, flat-fielding, and flipping) : 7 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R007.fits
# reducing (debias, flat-fielding, and flipping) : 8 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R008.fits
# reducing (debias, flat-fielding, and flipping) : 9 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R009.fits
# reducing (debias, flat-fielding, and flipping) : 10 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R010.fits
# reducing (debias, flat-fielding, and flipping) : 11 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R011.fits
# reducing (debias, flat-fielding, and flipping) : 12 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R012.fits
# reducing (debias, flat-fielding, and flipping) : 13 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R013.fits
# reducing (debias, flat-fielding, and flipping) : 14 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R014.fits
# reducing (debias, flat-fielding, and flipping) : 15 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R015.fits
# reducing (debias, flat-fielding, and flipping) : 16 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R016.fits
# reducing (debias, flat-fielding, and flipping) : 17 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R017.fits
# reducing (debias, flat-fielding, and flipping) : 18 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R018.fits
# reducing (debias, flat-fielding, and flipping) : 19 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R019.fits
# reducing (debias, flat-fielding, and flipping) : 20 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R020.fits
# reducing (debias, flat-fielding, and flipping) : 21 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R021.fits
# reducing (debias, flat-fielding, and flipping) : 22 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R022.fits
# reducing (debias, flat-fielding, and flipping) : 23 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R023.fits
# reducing (debias, flat-fielding, and flipping) : 24 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R024.fits
# reducing (debias, flat-fielding, and flipping) : 25 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R025.fits
# reducing (debias, flat-fielding, and flipping) : 26 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R026.fits
# reducing (debias, flat-fielding, and flipping) : 27 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R027.fits
# reducing (debias, flat-fielding, and flipping) : 28 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R028.fits
# reducing (debias, flat-fielding, and flipping) : 29 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R029.fits
# reducing (debias, flat-fielding, and flipping) : 30 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R030.fits
# reducing (debias, flat-fielding, and flipping) : 31 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R031.fits
# reducing (debias, flat-fielding, and flipping) : 32 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R032.fits
# reducing (debias, flat-fielding, and flipping) : 33 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R033.fits
# reducing (debias, flat-fielding, and flipping) : 34 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R034.fits
# reducing (debias, flat-fielding, and flipping) : 35 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R035.fits
# reducing (debias, flat-fielding, and flipping) : 36 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R036.fits
# reducing (debias, flat-fielding, and flipping) : 37 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R037.fits
# reducing (debias, flat-fielding, and flipping) : 38 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R038.fits
# reducing (debias, flat-fielding, and flipping) : 39 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R039.fits
# reducing (debias, flat-fielding, and flipping) : 40 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R040.fits
# reducing (debias, flat-fielding, and flipping) : 41 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R041.fits
# reducing (debias, flat-fielding, and flipping) : 42 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R042.fits
# reducing (debias, flat-fielding, and flipping) : 43 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R043.fits
# reducing (debias, flat-fielding, and flipping) : 44 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R044.fits
# reducing (debias, flat-fielding, and flipping) : 45 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R045.fits
# reducing (debias, flat-fielding, and flipping) : 46 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R046.fits
# reducing (debias, flat-fielding, and flipping) : 47 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R047.fits
# reducing (debias, flat-fielding, and flipping) : 48 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R048.fits
# reducing (debias, flat-fielding, and flipping) : 49 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R049.fits
# reducing (debias, flat-fielding, and flipping) : 50 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R050.fits
# reducing (debias, flat-fielding, and flipping) : 51 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R052.fits
# reducing (debias, flat-fielding, and flipping) : 52 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R053.fits
# reducing (debias, flat-fielding, and flipping) : 53 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R054.fits
# reducing (debias, flat-fielding, and flipping) : 54 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R055.fits
# reducing (debias, flat-fielding, and flipping) : 55 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R056.fits
# reducing (debias, flat-fielding, and flipping) : 56 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R057.fits
# reducing (debias, flat-fielding, and flipping) : 57 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R058.fits
# reducing (debias, flat-fielding, and flipping) : 58 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R059.fits
# reducing (debias, flat-fielding, and flipping) : 59 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R060.fits
# reducing (debias, flat-fielding, and flipping) : 60 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R061.fits
# reducing (debias, flat-fielding, and flipping) : 61 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R062.fits
# reducing (debias, flat-fielding, and flipping) : 62 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R063.fits
# reducing (debias, flat-fielding, and flipping) : 63 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R064.fits
# reducing (debias, flat-fielding, and flipping) : 64 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R065.fits
# reducing (debias, flat-fielding, and flipping) : 65 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R066.fits
# reducing (debias, flat-fielding, and flipping) : 66 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R067.fits
# reducing (debias, flat-fielding, and flipping) : 67 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R068.fits
# reducing (debias, flat-fielding, and flipping) : 68 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R069.fits
# reducing (debias, flat-fielding, and flipping) : 69 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R070.fits
# reducing (debias, flat-fielding, and flipping) : 70 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R071.fits
# reducing (debias, flat-fielding, and flipping) : 71 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R072.fits
# reducing (debias, flat-fielding, and flipping) : 72 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R073.fits
# reducing (debias, flat-fielding, and flipping) : 73 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R074.fits
# reducing (debias, flat-fielding, and flipping) : 74 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R075.fits
# reducing (debias, flat-fielding, and flipping) : 75 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R076.fits
# reducing (debias, flat-fielding, and flipping) : 76 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R077.fits
# reducing (debias, flat-fielding, and flipping) : 77 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R078.fits
# reducing (debias, flat-fielding, and flipping) : 78 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R079.fits
# reducing (debias, flat-fielding, and flipping) : 79 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R080.fits
# reducing (debias, flat-fielding, and flipping) : 80 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R081.fits
# reducing (debias, flat-fielding, and flipping) : 81 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R082.fits
# reducing (debias, flat-fielding, and flipping) : 82 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R083.fits
# reducing (debias, flat-fielding, and flipping) : 83 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R085.fits
# reducing (debias, flat-fielding, and flipping) : 84 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R086.fits
# reducing (debias, flat-fielding, and flipping) : 85 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R087.fits
# reducing (debias, flat-fielding, and flipping) : 86 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R088.fits
# reducing (debias, flat-fielding, and flipping) : 87 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R089.fits
# reducing (debias, flat-fielding, and flipping) : 88 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R090.fits
# reducing (debias, flat-fielding, and flipping) : 89 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R091.fits
# reducing (debias, flat-fielding, and flipping) : 90 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R092.fits
# reducing (debias, flat-fielding, and flipping) : 91 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R093.fits
# reducing (debias, flat-fielding, and flipping) : 92 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R094.fits
# reducing (debias, flat-fielding, and flipping) : 93 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R095.fits
# reducing (debias, flat-fielding, and flipping) : 94 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R096.fits
# reducing (debias, flat-fielding, and flipping) : 95 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R097.fits
# reducing (debias, flat-fielding, and flipping) : 96 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R098.fits
# reducing (debias, flat-fielding, and flipping) : 97 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R099.fits
# reducing (debias, flat-fielding, and flipping) : 98 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R100.fits
# reducing (debias, flat-fielding, and flipping) : 99 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R101.fits
# reducing (debias, flat-fielding, and flipping) : 100 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R102.fits
# reducing (debias, flat-fielding, and flipping) : 101 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R103.fits
# reducing (debias, flat-fielding, and flipping) : 102 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R104.fits
# reducing (debias, flat-fielding, and flipping) : 103 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R105.fits
# reducing (debias, flat-fielding, and flipping) : 104 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R106.fits
# reducing (debias, flat-fielding, and flipping) : 105 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R107.fits
# reducing (debias, flat-fielding, and flipping) : 106 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R108.fits
# reducing (debias, flat-fielding, and flipping) : 107 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R109.fits
# reducing (debias, flat-fielding, and flipping) : 108 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R110.fits
# reducing (debias, flat-fielding, and flipping) : 109 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R111.fits
# reducing (debias, flat-fielding, and flipping) : 110 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R112.fits
# reducing (debias, flat-fielding, and flipping) : 111 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R113.fits
# reducing (debias, flat-fielding, and flipping) : 112 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R114.fits
# reducing (debias, flat-fielding, and flipping) : 113 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R115.fits
# reducing (debias, flat-fielding, and flipping) : 114 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R116.fits
# reducing (debias, flat-fielding, and flipping) : 115 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R117.fits
# reducing (debias, flat-fielding, and flipping) : 116 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R118.fits
# reducing (debias, flat-fielding, and flipping) : 117 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R119.fits
# reducing (debias, flat-fielding, and flipping) : 118 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R120.fits
# reducing (debias, flat-fielding, and flipping) : 119 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R121.fits
# reducing (debias, flat-fielding, and flipping) : 120 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R122.fits
# reducing (debias, flat-fielding, and flipping) : 121 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R123.fits
# reducing (debias, flat-fielding, and flipping) : 122 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R124.fits
# reducing (debias, flat-fielding, and flipping) : 123 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R125.fits
# reducing (debias, flat-fielding, and flipping) : 124 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R126.fits
# reducing (debias, flat-fielding, and flipping) : 125 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R127.fits
# reducing (debias, flat-fielding, and flipping) : 126 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R128.fits
# reducing (debias, flat-fielding, and flipping) : 127 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R129.fits
# reducing (debias, flat-fielding, and flipping) : 128 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R130.fits
# reducing (debias, flat-fielding, and flipping) : 129 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R131.fits
# reducing (debias, flat-fielding, and flipping) : 130 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R132.fits
# reducing (debias, flat-fielding, and flipping) : 131 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R133.fits
# reducing (debias, flat-fielding, and flipping) : 132 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R134.fits
# reducing (debias, flat-fielding, and flipping) : 133 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R135.fits
# reducing (debias, flat-fielding, and flipping) : 134 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R136.fits
# reducing (debias, flat-fielding, and flipping) : 135 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R137.fits
# reducing (debias, flat-fielding, and flipping) : 136 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R138.fits
# reducing (debias, flat-fielding, and flipping) : 137 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R139.fits
# reducing (debias, flat-fielding, and flipping) : 138 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R140.fits
# reducing (debias, flat-fielding, and flipping) : 139 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R141.fits
# reducing (debias, flat-fielding, and flipping) : 140 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R142.fits
# reducing (debias, flat-fielding, and flipping) : 141 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R143.fits
# reducing (debias, flat-fielding, and flipping) : 142 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R144.fits
# reducing (debias, flat-fielding, and flipping) : 143 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R145.fits
# reducing (debias, flat-fielding, and flipping) : 144 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R146.fits
# reducing (debias, flat-fielding, and flipping) : 145 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R147.fits
# reducing (debias, flat-fielding, and flipping) : 146 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R148.fits
# reducing (debias, flat-fielding, and flipping) : 147 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R149.fits
# reducing (debias, flat-fielding, and flipping) : 148 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R150.fits
# reducing (debias, flat-fielding, and flipping) : 149 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R151.fits
# reducing (debias, flat-fielding, and flipping) : 150 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R152.fits
# reducing (debias, flat-fielding, and flipping) : 151 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R153.fits
# reducing (debias, flat-fielding, and flipping) : 152 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R154.fits
# reducing (debias, flat-fielding, and flipping) : 153 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R155.fits
# reducing (debias, flat-fielding, and flipping) : 154 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R156.fits
# reducing (debias, flat-fielding, and flipping) : 155 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R157.fits
# reducing (debias, flat-fielding, and flipping) : 156 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R158.fits
# reducing (debias, flat-fielding, and flipping) : 157 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R159.fits
# reducing (debias, flat-fielding, and flipping) : 158 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R160.fits
# reducing (debias, flat-fielding, and flipping) : 159 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R161.fits
# reducing (debias, flat-fielding, and flipping) : 160 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R162.fits
# reducing (debias, flat-fielding, and flipping) : 161 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R163.fits
# reducing (debias, flat-fielding, and flipping) : 162 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R164.fits
# reducing (debias, flat-fielding, and flipping) : 163 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R165.fits
# reducing (debias, flat-fielding, and flipping) : 164 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R166.fits
# reducing (debias, flat-fielding, and flipping) : 165 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R167.fits
# reducing (debias, flat-fielding, and flipping) : 166 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R168.fits
# reducing (debias, flat-fielding, and flipping) : 167 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R169.fits
# reducing (debias, flat-fielding, and flipping) : 168 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R170.fits
# reducing (debias, flat-fielding, and flipping) : 169 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R171.fits
# reducing (debias, flat-fielding, and flipping) : 170 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R172.fits
# reducing (debias, flat-fielding, and flipping) : 171 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R173.fits
# reducing (debias, flat-fielding, and flipping) : 172 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R174.fits
# reducing (debias, flat-fielding, and flipping) : 173 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R175.fits
# reducing (debias, flat-fielding, and flipping) : 174 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R176.fits
# reducing (debias, flat-fielding, and flipping) : 175 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R177.fits
# reducing (debias, flat-fielding, and flipping) : 176 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R178.fits
# reducing (debias, flat-fielding, and flipping) : 177 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R179.fits
# reducing (debias, flat-fielding, and flipping) : 178 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R180.fits
# reducing (debias, flat-fielding, and flipping) : 179 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R181.fits
# reducing (debias, flat-fielding, and flipping) : 180 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R182.fits
# reducing (debias, flat-fielding, and flipping) : 181 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R183.fits
# reducing (debias, flat-fielding, and flipping) : 182 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R184.fits
# reducing (debias, flat-fielding, and flipping) : 183 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R185.fits
# reducing (debias, flat-fielding, and flipping) : 184 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R186.fits
# reducing (debias, flat-fielding, and flipping) : 185 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R187.fits
# reducing (debias, flat-fielding, and flipping) : 186 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R188.fits
# reducing (debias, flat-fielding, and flipping) : 187 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R189.fits
# reducing (debias, flat-fielding, and flipping) : 188 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R190.fits
# reducing (debias, flat-fielding, and flipping) : 189 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R191.fits
# reducing (debias, flat-fielding, and flipping) : 190 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R192.fits
# reducing (debias, flat-fielding, and flipping) : 191 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R193.fits
# reducing (debias, flat-fielding, and flipping) : 192 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R194.fits
# reducing (debias, flat-fielding, and flipping) : 193 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R195.fits
# reducing (debias, flat-fielding, and flipping) : 194 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R196.fits
# reducing (debias, flat-fielding, and flipping) : 195 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R197.fits
# reducing (debias, flat-fielding, and flipping) : 196 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R198.fits
# reducing (debias, flat-fielding, and flipping) : 197 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R199.fits
# reducing (debias, flat-fielding, and flipping) : 198 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R200.fits
# reducing (debias, flat-fielding, and flipping) : 199 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R201.fits
# reducing (debias, flat-fielding, and flipping) : 200 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R202.fits
# reducing (debias, flat-fielding, and flipping) : 201 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R203.fits
# reducing (debias, flat-fielding, and flipping) : 202 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R204.fits
# reducing (debias, flat-fielding, and flipping) : 203 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R205.fits
# reducing (debias, flat-fielding, and flipping) : 204 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R206.fits
# reducing (debias, flat-fielding, and flipping) : 205 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R207.fits
# reducing (debias, flat-fielding, and flipping) : 206 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R208.fits
# reducing (debias, flat-fielding, and flipping) : 207 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R209.fits
# reducing (debias, flat-fielding, and flipping) : 208 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R210.fits
# reducing (debias, flat-fielding, and flipping) : 209 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R211.fits
# reducing (debias, flat-fielding, and flipping) : 210 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R212.fits
# reducing (debias, flat-fielding, and flipping) : 211 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R213.fits
# reducing (debias, flat-fielding, and flipping) : 212 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R214.fits
# reducing (debias, flat-fielding, and flipping) : 213 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R215.fits
# reducing (debias, flat-fielding, and flipping) : 214 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R216.fits
# reducing (debias, flat-fielding, and flipping) : 215 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R217.fits
# reducing (debias, flat-fielding, and flipping) : 216 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R218.fits
# reducing (debias, flat-fielding, and flipping) : 217 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R219.fits
# reducing (debias, flat-fielding, and flipping) : 218 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R220.fits
# reducing (debias, flat-fielding, and flipping) : 219 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R221.fits
# reducing (debias, flat-fielding, and flipping) : 220 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R222.fits
# reducing (debias, flat-fielding, and flipping) : 221 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R223.fits
# reducing (debias, flat-fielding, and flipping) : 222 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R224.fits
# reducing (debias, flat-fielding, and flipping) : 223 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R226.fits
# reducing (debias, flat-fielding, and flipping) : 224 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R227.fits
# reducing (debias, flat-fielding, and flipping) : 225 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R228.fits
# reducing (debias, flat-fielding, and flipping) : 226 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R229.fits
# reducing (debias, flat-fielding, and flipping) : 227 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R230.fits
# reducing (debias, flat-fielding, and flipping) : 228 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R231.fits
# reducing (debias, flat-fielding, and flipping) : 229 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R232.fits
# reducing (debias, flat-fielding, and flipping) : 230 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R233.fits
# reducing (debias, flat-fielding, and flipping) : 231 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R234.fits
# reducing (debias, flat-fielding, and flipping) : 232 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R235.fits
# reducing (debias, flat-fielding, and flipping) : 233 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R236.fits
# reducing (debias, flat-fielding, and flipping) : 234 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R237.fits
# reducing (debias, flat-fielding, and flipping) : 235 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R238.fits
# reducing (debias, flat-fielding, and flipping) : 236 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R239.fits
# reducing (debias, flat-fielding, and flipping) : 237 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R240.fits
# reducing (debias, flat-fielding, and flipping) : 238 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R241.fits
# reducing (debias, flat-fielding, and flipping) : 239 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R242.fits
# reducing (debias, flat-fielding, and flipping) : 240 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R243.fits
# reducing (debias, flat-fielding, and flipping) : 241 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R244.fits
# reducing (debias, flat-fielding, and flipping) : 242 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R245.fits
# reducing (debias, flat-fielding, and flipping) : 243 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R246.fits
# reducing (debias, flat-fielding, and flipping) : 244 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R247.fits
# reducing (debias, flat-fielding, and flipping) : 245 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R248.fits
# reducing (debias, flat-fielding, and flipping) : 246 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R249.fits
# reducing (debias, flat-fielding, and flipping) : 247 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R250.fits
# reducing (debias, flat-fielding, and flipping) : 248 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R251.fits
# reducing (debias, flat-fielding, and flipping) : 249 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R252.fits
# reducing (debias, flat-fielding, and flipping) : 250 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R253.fits
# reducing (debias, flat-fielding, and flipping) : 251 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R254.fits
# reducing (debias, flat-fielding, and flipping) : 252 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R255.fits
# reducing (debias, flat-fielding, and flipping) : 253 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R256.fits
# reducing (debias, flat-fielding, and flipping) : 254 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R257.fits
# reducing (debias, flat-fielding, and flipping) : 255 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R258.fits
# reducing (debias, flat-fielding, and flipping) : 256 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R259.fits
# reducing (debias, flat-fielding, and flipping) : 257 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R260.fits
# reducing (debias, flat-fielding, and flipping) : 258 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R261.fits
# reducing (debias, flat-fielding, and flipping) : 259 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R262.fits
# reducing (debias, flat-fielding, and flipping) : 260 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R263.fits
# reducing (debias, flat-fielding, and flipping) : 261 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R264.fits
# reducing (debias, flat-fielding, and flipping) : 262 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R265.fits
# reducing (debias, flat-fielding, and flipping) : 263 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R266.fits
# reducing (debias, flat-fielding, and flipping) : 264 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R267.fits
# reducing (debias, flat-fielding, and flipping) : 265 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R268.fits
# reducing (debias, flat-fielding, and flipping) : 266 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R269.fits
# reducing (debias, flat-fielding, and flipping) : 267 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R270.fits
# reducing (debias, flat-fielding, and flipping) : 268 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R271.fits
# reducing (debias, flat-fielding, and flipping) : 269 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R272.fits
# reducing (debias, flat-fielding, and flipping) : 270 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R273.fits
# reducing (debias, flat-fielding, and flipping) : 271 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R274.fits
# reducing (debias, flat-fielding, and flipping) : 272 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R275.fits
# reducing (debias, flat-fielding, and flipping) : 273 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R276.fits
# reducing (debias, flat-fielding, and flipping) : 274 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R277.fits
# reducing (debias, flat-fielding, and flipping) : 275 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R278.fits
# reducing (debias, flat-fielding, and flipping) : 276 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R279.fits
# reducing (debias, flat-fielding, and flipping) : 277 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R280.fits
# reducing (debias, flat-fielding, and flipping) : 278 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R281.fits
# reducing (debias, flat-fielding, and flipping) : 279 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R282.fits
# reducing (debias, flat-fielding, and flipping) : 280 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R283.fits
# reducing (debias, flat-fielding, and flipping) : 281 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R284.fits
# reducing (debias, flat-fielding, and flipping) : 282 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R285.fits
# reducing (debias, flat-fielding, and flipping) : 283 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R286.fits
# reducing (debias, flat-fielding, and flipping) : 284 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R287.fits
# reducing (debias, flat-fielding, and flipping) : 285 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R288.fits
# reducing (debias, flat-fielding, and flipping) : 286 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R289.fits
# reducing (debias, flat-fielding, and flipping) : 287 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R290.fits
# reducing (debias, flat-fielding, and flipping) : 288 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R291.fits
# reducing (debias, flat-fielding, and flipping) : 289 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R292.fits
# reducing (debias, flat-fielding, and flipping) : 290 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R293.fits
# reducing (debias, flat-fielding, and flipping) : 291 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R294.fits
# reducing (debias, flat-fielding, and flipping) : 292 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R295.fits
# reducing (debias, flat-fielding, and flipping) : 293 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R296.fits
# reducing (debias, flat-fielding, and flipping) : 294 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R297.fits
# reducing (debias, flat-fielding, and flipping) : 295 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R298.fits
# reducing (debias, flat-fielding, and flipping) : 296 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R299.fits
# reducing (debias, flat-fielding, and flipping) : 297 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R300.fits
# reducing (debias, flat-fielding, and flipping) : 298 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R301.fits
# reducing (debias, flat-fielding, and flipping) : 299 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R302.fits
# reducing (debias, flat-fielding, and flipping) : 300 300 /Users/applestore/exo-observe/Data/GJ-1214b/raw_data/d-UW32R303.fits
# writing to /Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/p-UW32R303.fits

# %%
# Next Performing Photometry:

# This step converts CCD counts to the physical flux. We don't make flux calibration here, since we aim to get 
# light curve from relative photometry (differential photometry)

# get sky and sky mask

# %%
#data=fits.getdata('/Users/applestore/exo-observe/Data/GJ-1214b/reduced_data/p-UW32R023.fits')
from photutils.segmentation import SegmentationImage
from photutils.utils import circular_footprint

## or first mask sources then estimate the sky background
sigma_clip = SigmaClip(sigma=3.0, maxiters=10)
threshold = detect_threshold(data, nsigma=2.0, sigma_clip=sigma_clip)
segment_img = detect_sources(data, threshold, npixels=10)
footprint = circular_footprint(radius=3)
mask = segment_img.make_source_mask(footprint=footprint)
mean, median, std = sigma_clipped_stats(data, sigma=3.0, mask=mask)
print((mean, median, std))
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING:astropy:Input data contains invalid values (NaNs or infs), which were automatically clipped.
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# WARNING:astropy:Input data contains invalid values (NaNs or infs), which were automatically clipped.
# (0.17521725990413758, 0.1749931724698441, 0.0032758272661451582)

# %%
## get 2D sky map
from astropy.stats import SigmaClip
sigma_clip = SigmaClip(sigma=3.)
bkg_estimator = pht.SExtractorBackground()
bkg = pht.Background2D(data, (64, 64), mask=mask, filter_size=(3, 3), sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)
# Out:
# /var/folders/kb/x7gy6w9569jgnxt7cz_dpm1m0000gn/T/ipykernel_5102/128542988.py:4: DeprecationWarning: `photutils.SExtractorBackground` is a deprecated alias for `photutils.background.SExtractorBackground` and will be removed in the future. Instead, please use `from photutils.background import SExtractorBackground` to silence this warning.
#   bkg_estimator = pht.SExtractorBackground()
# /var/folders/kb/x7gy6w9569jgnxt7cz_dpm1m0000gn/T/ipykernel_5102/128542988.py:5: DeprecationWarning: `photutils.Background2D` is a deprecated alias for `photutils.background.Background2D` and will be removed in the future. Instead, please use `from photutils.background import Background2D` to silence this warning.
#   bkg = pht.Background2D(data, (64, 64), mask=mask, filter_size=(3, 3), sigma_clip=sigma_clip, bkg_estimator=bkg_estimator)
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically masked. [photutils.background.background_2d]
# WARNING:astropy:Input data contains invalid values (NaNs or infs), which were automatically masked.

# %%
print(bkg.background_median,bkg.background_rms_median)
# Out:
# 0.17506444127480694 0.0008864949502488358

# %%
f,axs=plt.subplots(1,2,figsize=(16,8))
axs[0].imshow(bkg.background,origin='lower')
axs[0].set_title("background")
axs[1].imshow(bkg.background_rms,origin='lower')
axs[1].set_title("background rms")
# Out:
# Text(0.5, 1.0, 'background rms')

# %%
## find objects and calculate basic information
daofind = pht.IRAFStarFinder(fwhm=3.0, threshold=5.*bkg.background_rms_median,exclude_border=True, 
                             sharplo= 0.5, sharphi=2.0, roundlo=0.0, roundhi=0.7)
sources = daofind(data - bkg.background_median)
print(sources)
print(sources.colnames)
# Out:
# /var/folders/kb/x7gy6w9569jgnxt7cz_dpm1m0000gn/T/ipykernel_5102/2102493974.py:2: DeprecationWarning: `photutils.IRAFStarFinder` is a deprecated alias for `photutils.detection.IRAFStarFinder` and will be removed in the future. Instead, please use `from photutils.detection import IRAFStarFinder` to silence this warning.
#   daofind = pht.IRAFStarFinder(fwhm=3.0, threshold=5.*bkg.background_rms_median,exclude_border=True,
#  id     xcentroid          ycentroid             fwhm        ...          peak                 flux                 mag
# --- ------------------ ------------------ ------------------ ... --------------------- -------------------- -------------------
#   1  364.0167865489643 16.272555161257493  1.534908581893668 ...  0.013064824961688256 0.021710488110619097   4.158326030796766
#   2 104.69660838291624 26.198328738064994 1.9457368537282145 ...  0.005465883726000952 0.026299398655957137  3.9501354541924565
#   3  25.83530947508687 28.003667020808713 2.3362649515404246 ...    1.1099372991302863   13.186549216429034  -2.800327900098394
#   4  541.1749532428582  27.99918705515662 2.3361940165150976 ...    1.1117867159041905   13.092060070787179 -2.7925199733252404
#   5  48.89884763800805  32.80524353003616 1.7185769031886227 ...  0.009586126477186676 0.019219525281278283   4.290643358821055
#   6 309.69453071433014  40.79393759173894 1.7964414900314865 ... 0.0032556738787638444 0.017680357810988152    4.38127237520707
#   7  541.1723194559635  46.00030305938381 2.3359574049401224 ...    1.1048632136242844   13.075380783639496 -2.7911358633177654
#   8 25.833392343880142  48.99880484477977 2.3364132697710067 ...    1.1062221083397739   13.194308167128275  -2.800966558183347
#   9  389.7610485870552  52.84017749770358  1.801716095208551 ...  0.012929142715045142  0.03940781403140368  3.5110441374255035
#  10 441.74580646927393  57.05938632175277 1.5245848901949288 ...  0.006258366252097118 0.016082870623934813   4.484091079132664
#  11  541.1750440647604  58.99789548013202 2.3358102269073036 ...     1.104602038905662   13.063216976982021 -2.7901253510974855
#  12 25.833675906445283  68.00168410388044  2.336565029566687 ...     1.102951260584267    13.14816115515957 -2.7971625463212764
#  13  541.1720579789691  70.00005125021899 2.3356707662490823 ...    1.1027428950871712    13.08070681527121  -2.791578029251664
#  14 207.10701090803406  70.97390475707937  1.675682760486282 ...  0.009264198769150033  0.01720810707981817   4.410667250387278
#  15 25.833036667818295  80.99971229248169 2.3361533344198815 ...     1.108618955962812   13.142488732481603 -2.7966940333866743
# ...                ...                ...                ... ...                   ...                  ...                 ...
# 379  541.1744528415463 1994.9987572255068 2.3356478560493756 ...    1.1075092022583548   13.103249054945318  -2.793447489459939
# 380  17.04410054499694 1997.2333313511906 1.9222249074611288 ...   0.01997086372312573  0.08453574721215196  2.6823990106415363
# 381  530.9019216724472  2001.975171148871  1.542209360390884 ...  0.011431988802458706 0.017835022166061837  4.3718158664178866
# 382  25.83083974631762 2002.9971758547113  2.336805418044087 ...    1.1028601519515862    13.15902185009453 -2.7980590201373663
# 383  280.9454396279976 2003.1872282013242 1.7064307784023462 ...  0.010937622194210284 0.022443898348565382   4.122254267355633
# 384  541.1729572031641 2009.0002336185948 2.3362364314233206 ...    1.1097452630154931   13.115370083562011 -2.7944513745597677
# 385  25.83253928720362 2012.0005582535653  2.336303849309197 ...    1.1136594448022765   13.210500672048003 -2.8022981937310973
# 386  550.2491594123244 2014.8389930987983 1.8367617692294587 ...  0.016567869789415823  0.04617114811737766  3.3390733147677967
# 387  343.0749549874657 2019.7571100342839 1.5760534925632537 ...  0.008121171371238889 0.016867065736097437   4.432401156221191
# 388  25.83131833151002  2021.000276796033  2.336968470579447 ...    1.1131104910767013   13.171065951878957  -2.799052311034954
# 389  551.1962942640116 2026.0638481378376 1.6035819945810585 ...  0.008447109816797305  0.02370540109560082   4.062881730040745
# 390  541.1709240110687 2030.9994278669565 2.3363281900462107 ...    1.1013666430521933   13.110125994331996  -2.794017163698933
# 391 25.834098579764902  2037.001426511834 2.3362875270110943 ...     1.107453843987341   13.219788692963848 -2.8030612834464415
# 392 133.88266322097613   2038.23954584675 1.5723656720620331 ...   0.00616775114178496  0.01288632882546907   4.724676976967298
# 393  492.8289369704551  2042.021985043217 1.5624305973397592 ...  0.006145842074339124  0.01160891277542267   4.838021129754442
# Length = 393 rows
# ['id', 'xcentroid', 'ycentroid', 'fwhm', 'sharpness', 'roundness', 'pa', 'npix', 'sky', 'peak', 'flux', 'mag']
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/photutils/detection/irafstarfinder.py:382: RuntimeWarning: invalid value encountered in multiply
#   sky = (np.sum(self.cutout_data_nosub * skymask, axis=axis)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
from photutils import CircularAperture
positions = np.transpose((sources['xcentroid'], sources['ycentroid']))
apertures = CircularAperture(positions, r=10.)
plt.figure(figsize=(8,8))
plt.imshow(data, cmap='Greys_r', origin='lower', vmin=300,vmax=600, interpolation='nearest') 
apertures.plot(color='red', lw=1.5, alpha=0.5)
# Out:
# /var/folders/kb/x7gy6w9569jgnxt7cz_dpm1m0000gn/T/ipykernel_5102/2284856856.py:1: DeprecationWarning: `photutils.CircularAperture` is a deprecated alias for `photutils.aperture.CircularAperture` and will be removed in the future. Instead, please use `from photutils.aperture import CircularAperture` to silence this warning.
#   from photutils import CircularAperture
# [<matplotlib.patches.Circle at 0x11d95b3e0>,
#  <matplotlib.patches.Circle at 0x11d277a70>,
#  <matplotlib.patches.Circle at 0x11bcfe7b0>,
#  <matplotlib.patches.Circle at 0x11bcfdf70>,
#  <matplotlib.patches.Circle at 0x11bcfff20>,
#  <matplotlib.patches.Circle at 0x11bcfe9f0>,
#  <matplotlib.patches.Circle at 0x11bcfe960>,
#  <matplotlib.patches.Circle at 0x11bcff920>,
#  <matplotlib.patches.Circle at 0x11bcff2f0>,
#  <matplotlib.patches.Circle at 0x11bcfe810>,
#  <matplotlib.patches.Circle at 0x11bcfc500>,
#  <matplotlib.patches.Circle at 0x11bcff1d0>,
#  <matplotlib.patches.Circle at 0x11d1900e0>,
#  <matplotlib.patches.Circle at 0x11d1901d0>,
#  <matplotlib.patches.Circle at 0x11d1902c0>,
#  <matplotlib.patches.Circle at 0x11d1903b0>,
#  <matplotlib.patches.Circle at 0x11d190440>,
#  <matplotlib.patches.Circle at 0x11d190560>,
#  <matplotlib.patches.Circle at 0x11d1905f0>,
#  <matplotlib.patches.Circle at 0x11bd1b8c0>,
#  <matplotlib.patches.Circle at 0x11d1906b0>,
#  <matplotlib.patches.Circle at 0x11d1907d0>,
#  <matplotlib.patches.Circle at 0x11d1908c0>,
#  <matplotlib.patches.Circle at 0x11d1909b0>,
#  <matplotlib.patches.Circle at 0x11d190a40>,
#  <matplotlib.patches.Circle at 0x11d190b60>,
#  <matplotlib.patches.Circle at 0x11d190bf0>,
#  <matplotlib.patches.Circle at 0x11d190dd0>,
#  <matplotlib.patches.Circle at 0x11d190e60>,
#  <matplotlib.patches.Circle at 0x11d190f80>,
#  <matplotlib.patches.Circle at 0x11d191040>,
#  <matplotlib.patches.Circle at 0x11d1910d0>,
#  <matplotlib.patches.Circle at 0x11d191130>,
#  <matplotlib.patches.Circle at 0x11d191280>,
#  <matplotlib.patches.Circle at 0x11d191370>,
#  <matplotlib.patches.Circle at 0x11d191460>,
#  <matplotlib.patches.Circle at 0x11d191550>,
#  <matplotlib.patches.Circle at 0x11d191640>,
#  <matplotlib.patches.Circle at 0x11d1916d0>,
#  <matplotlib.patches.Circle at 0x11d1917c0>,
#  <matplotlib.patches.Circle at 0x11d1918b0>,
#  <matplotlib.patches.Circle at 0x11d191940>,
#  <matplotlib.patches.Circle at 0x11d191a60>,
#  <matplotlib.patches.Circle at 0x11d191af0>,
#  <matplotlib.patches.Circle at 0x11d191c10>,
#  <matplotlib.patches.Circle at 0x11d191d00>,
#  <matplotlib.patches.Circle at 0x11d191df0>,
#  <matplotlib.patches.Circle at 0x11d191ee0>,
#  <matplotlib.patches.Circle at 0x11d191f70>,
#  <matplotlib.patches.Circle at 0x11d192060>,
#  <matplotlib.patches.Circle at 0x11d192150>,
#  <matplotlib.patches.Circle at 0x11d192240>,
#  <matplotlib.patches.Circle at 0x11d1922d0>,
#  <matplotlib.patches.Circle at 0x11d192390>,
#  <matplotlib.patches.Circle at 0x11d1924b0>,
#  <matplotlib.patches.Circle at 0x11d1925a0>,
#  <matplotlib.patches.Circle at 0x11d192630>,
#  <matplotlib.patches.Circle at 0x11d1926f0>,
#  <matplotlib.patches.Circle at 0x11d192810>,
#  <matplotlib.patches.Circle at 0x11d1928d0>,
#  <matplotlib.patches.Circle at 0x11d1929c0>,
#  <matplotlib.patches.Circle at 0x11d192a50>,
#  <matplotlib.patches.Circle at 0x11d192b70>,
#  <matplotlib.patches.Circle at 0x11d192c60>,
#  <matplotlib.patches.Circle at 0x11d192d50>,
#  <matplotlib.patches.Circle at 0x11d192e40>,
#  <matplotlib.patches.Circle at 0x11d192f30>,
#  <matplotlib.patches.Circle at 0x11d193020>,
#  <matplotlib.patches.Circle at 0x11d193110>,
#  <matplotlib.patches.Circle at 0x11d193200>,
#  <matplotlib.patches.Circle at 0x11d1932f0>,
#  <matplotlib.patches.Circle at 0x11d1933e0>,
#  <matplotlib.patches.Circle at 0x11d1934d0>,
#  <matplotlib.patches.Circle at 0x11d1935c0>,
#  <matplotlib.patches.Circle at 0x11d193650>,
#  <matplotlib.patches.Circle at 0x11d193770>,
#  <matplotlib.patches.Circle at 0x11d193860>,
#  <matplotlib.patches.Circle at 0x11d193950>,
#  <matplotlib.patches.Circle at 0x11d193a40>,
#  <matplotlib.patches.Circle at 0x11d193b00>,
#  <matplotlib.patches.Circle at 0x11d193bf0>,
#  <matplotlib.patches.Circle at 0x11d193ce0>,
#  <matplotlib.patches.Circle at 0x11d193dd0>,
#  <matplotlib.patches.Circle at 0x11d193ec0>,
#  <matplotlib.patches.Circle at 0x11d193fb0>,
#  <matplotlib.patches.Circle at 0x11d1c40b0>,
#  <matplotlib.patches.Circle at 0x11d1c41a0>,
#  <matplotlib.patches.Circle at 0x11d1c4290>,
#  <matplotlib.patches.Circle at 0x11d1c4380>,
#  <matplotlib.patches.Circle at 0x11d1c4470>,
#  <matplotlib.patches.Circle at 0x11d1c4560>,
#  <matplotlib.patches.Circle at 0x11d1c4650>,
#  <matplotlib.patches.Circle at 0x11d1c4740>,
#  <matplotlib.patches.Circle at 0x11d1c4830>,
#  <matplotlib.patches.Circle at 0x11d1c4920>,
#  <matplotlib.patches.Circle at 0x11d1c4a10>,
#  <matplotlib.patches.Circle at 0x11d1c4b00>,
#  <matplotlib.patches.Circle at 0x11d1c4bf0>,
#  <matplotlib.patches.Circle at 0x11d1c4ce0>,
#  <matplotlib.patches.Circle at 0x11d1c4dd0>,
#  <matplotlib.patches.Circle at 0x11d1c4ec0>,
#  <matplotlib.patches.Circle at 0x11d1c4fb0>,
#  <matplotlib.patches.Circle at 0x11d1c5070>,
#  <matplotlib.patches.Circle at 0x11d1c5130>,
#  <matplotlib.patches.Circle at 0x11d1c51f0>,
#  <matplotlib.patches.Circle at 0x11d1c52b0>,
#  <matplotlib.patches.Circle at 0x11d1c5370>,
#  <matplotlib.patches.Circle at 0x11d1c5400>,
#  <matplotlib.patches.Circle at 0x11d1c54c0>,
#  <matplotlib.patches.Circle at 0x11d1c5550>,
#  <matplotlib.patches.Circle at 0x11d1c5610>,
#  <matplotlib.patches.Circle at 0x11d1c56d0>,
#  <matplotlib.patches.Circle at 0x11d1c5790>,
#  <matplotlib.patches.Circle at 0x11d1c5850>,
#  <matplotlib.patches.Circle at 0x11d1c5910>,
#  <matplotlib.patches.Circle at 0x11d1c59d0>,
#  <matplotlib.patches.Circle at 0x11d1c5a90>,
#  <matplotlib.patches.Circle at 0x11d1c5b50>,
#  <matplotlib.patches.Circle at 0x11d1c5c10>,
#  <matplotlib.patches.Circle at 0x11d1c5cd0>,
#  <matplotlib.patches.Circle at 0x11d1c5d90>,
#  <matplotlib.patches.Circle at 0x11d1c5e50>,
#  <matplotlib.patches.Circle at 0x11d1c5f10>,
#  <matplotlib.patches.Circle at 0x11d1c5fd0>,
#  <matplotlib.patches.Circle at 0x11dcf89b0>,
#  <matplotlib.patches.Circle at 0x11dcf8b60>,
#  <matplotlib.patches.Circle at 0x11dcfb560>,
#  <matplotlib.patches.Circle at 0x11dcfbb60>,
#  <matplotlib.patches.Circle at 0x11dcfbce0>,
#  <matplotlib.patches.Circle at 0x11dcfbcb0>,
#  <matplotlib.patches.Circle at 0x11df07b30>,
#  <matplotlib.patches.Circle at 0x11df07950>,
#  <matplotlib.patches.Circle at 0x11cf3bf20>,
#  <matplotlib.patches.Circle at 0x11cf3bcb0>,
#  <matplotlib.patches.Circle at 0x11dce8dd0>,
#  <matplotlib.patches.Circle at 0x11dce9580>,
#  <matplotlib.patches.Circle at 0x11deb92b0>,
#  <matplotlib.patches.Circle at 0x11deb9970>,
#  <matplotlib.patches.Circle at 0x11deba0f0>,
#  <matplotlib.patches.Circle at 0x11deb8b30>,
#  <matplotlib.patches.Circle at 0x11debbb90>,
#  <matplotlib.patches.Circle at 0x11bc1ab70>,
#  <matplotlib.patches.Circle at 0x11df72540>,
#  <matplotlib.patches.Circle at 0x11df70ef0>,
#  <matplotlib.patches.Circle at 0x11df701a0>,
#  <matplotlib.patches.Circle at 0x11df705c0>,
#  <matplotlib.patches.Circle at 0x11df71580>,
#  <matplotlib.patches.Circle at 0x11df73fb0>,
#  <matplotlib.patches.Circle at 0x11df70d10>,
#  <matplotlib.patches.Circle at 0x11df72b10>,
#  <matplotlib.patches.Circle at 0x11df70980>,
#  <matplotlib.patches.Circle at 0x11de97dd0>,
#  <matplotlib.patches.Circle at 0x11de964e0>,
#  <matplotlib.patches.Circle at 0x11ddc5910>,
#  <matplotlib.patches.Circle at 0x11ddc7bc0>,
#  <matplotlib.patches.Circle at 0x11ddc65d0>,
#  <matplotlib.patches.Circle at 0x11ddc5f10>,
#  <matplotlib.patches.Circle at 0x11ddc7d10>,
#  <matplotlib.patches.Circle at 0x11ddc7e60>,
#  <matplotlib.patches.Circle at 0x11ddc7770>,
#  <matplotlib.patches.Circle at 0x11ddc6ff0>,
#  <matplotlib.patches.Circle at 0x11ddc7d40>,
#  <matplotlib.patches.Circle at 0x11ddc4560>,
#  <matplotlib.patches.Circle at 0x11ddc4e60>,
#  <matplotlib.patches.Circle at 0x11ddc4860>,
#  <matplotlib.patches.Circle at 0x11ddc5b80>,
#  <matplotlib.patches.Circle at 0x11ddc4770>,
#  <matplotlib.patches.Circle at 0x11ddc76e0>,
#  <matplotlib.patches.Circle at 0x11ddc6600>,
#  <matplotlib.patches.Circle at 0x11ddc54c0>,
#  <matplotlib.patches.Circle at 0x11ddc5d30>,
#  <matplotlib.patches.Circle at 0x11ddc7230>,
#  <matplotlib.patches.Circle at 0x11df0c110>,
#  <matplotlib.patches.Circle at 0x11df0ea20>,
#  <matplotlib.patches.Circle at 0x11df0c170>,
#  <matplotlib.patches.Circle at 0x11df0c260>,
#  <matplotlib.patches.Circle at 0x11df0d880>,
#  <matplotlib.patches.Circle at 0x11df0dc40>,
#  <matplotlib.patches.Circle at 0x11de4ef30>,
#  <matplotlib.patches.Circle at 0x11de4cbf0>,
#  <matplotlib.patches.Circle at 0x11de4ec90>,
#  <matplotlib.patches.Circle at 0x11de4c9b0>,
#  <matplotlib.patches.Circle at 0x11de4eed0>,
#  <matplotlib.patches.Circle at 0x11de4fad0>,
#  <matplotlib.patches.Circle at 0x11de4ea50>,
#  <matplotlib.patches.Circle at 0x11de4cb60>,
#  <matplotlib.patches.Circle at 0x11de4f230>,
#  <matplotlib.patches.Circle at 0x11de4dee0>,
#  <matplotlib.patches.Circle at 0x11de4d1c0>,
#  <matplotlib.patches.Circle at 0x11de4f9e0>,
#  <matplotlib.patches.Circle at 0x11de4deb0>,
#  <matplotlib.patches.Circle at 0x11de4e7b0>,
#  <matplotlib.patches.Circle at 0x11de4f7d0>,
#  <matplotlib.patches.Circle at 0x11de4d070>,
#  <matplotlib.patches.Circle at 0x11de4f650>,
#  <matplotlib.patches.Circle at 0x11de4e6f0>,
#  <matplotlib.patches.Circle at 0x11de4d970>,
#  <matplotlib.patches.Circle at 0x11de4c7a0>,
#  <matplotlib.patches.Circle at 0x11de4cad0>,
#  <matplotlib.patches.Circle at 0x11de4d190>,
#  <matplotlib.patches.Circle at 0x11de4fe30>,
#  <matplotlib.patches.Circle at 0x11de4f080>,
#  <matplotlib.patches.Circle at 0x11de4f8c0>,
#  <matplotlib.patches.Circle at 0x11de4f020>,
#  <matplotlib.patches.Circle at 0x11de4de20>,
#  <matplotlib.patches.Circle at 0x11de4d4c0>,
#  <matplotlib.patches.Circle at 0x11de4fda0>,
#  <matplotlib.patches.Circle at 0x11de4ca70>,
#  <matplotlib.patches.Circle at 0x11de4fd70>,
#  <matplotlib.patches.Circle at 0x11de4d580>,
#  <matplotlib.patches.Circle at 0x11de4c710>,
#  <matplotlib.patches.Circle at 0x11de4cda0>,
#  <matplotlib.patches.Circle at 0x11de4ca40>,
#  <matplotlib.patches.Circle at 0x11de4df40>,
#  <matplotlib.patches.Circle at 0x11de4c5c0>,
#  <matplotlib.patches.Circle at 0x11de4c200>,
#  <matplotlib.patches.Circle at 0x11de4c980>,
#  <matplotlib.patches.Circle at 0x11de4cec0>,
#  <matplotlib.patches.Circle at 0x11de4ef60>,
#  <matplotlib.patches.Circle at 0x11de4f5f0>,
#  <matplotlib.patches.Circle at 0x11de4cb90>,
#  <matplotlib.patches.Circle at 0x11de4e690>,
#  <matplotlib.patches.Circle at 0x11de4f680>,
#  <matplotlib.patches.Circle at 0x11de4c1a0>,
#  <matplotlib.patches.Circle at 0x11de4d9a0>,
#  <matplotlib.patches.Circle at 0x11de4fc50>,
#  <matplotlib.patches.Circle at 0x11de4ce00>,
#  <matplotlib.patches.Circle at 0x11de4c830>,
#  <matplotlib.patches.Circle at 0x11de4f1a0>,
#  <matplotlib.patches.Circle at 0x11de4f890>,
#  <matplotlib.patches.Circle at 0x11de4f950>,
#  <matplotlib.patches.Circle at 0x11de4e8a0>,
#  <matplotlib.patches.Circle at 0x11de4fc80>,
#  <matplotlib.patches.Circle at 0x11de4d2e0>,
#  <matplotlib.patches.Circle at 0x11de4fbc0>,
#  <matplotlib.patches.Circle at 0x11de4dd30>,
#  <matplotlib.patches.Circle at 0x11de4f4d0>,
#  <matplotlib.patches.Circle at 0x11de4f140>,
#  <matplotlib.patches.Circle at 0x11de4db20>,
#  <matplotlib.patches.Circle at 0x11dee0950>,
#  <matplotlib.patches.Circle at 0x11dee0800>,
#  <matplotlib.patches.Circle at 0x11dee09e0>,
#  <matplotlib.patches.Circle at 0x11dee04a0>,
#  <matplotlib.patches.Circle at 0x11dee1130>,
#  <matplotlib.patches.Circle at 0x11dee2db0>,
#  <matplotlib.patches.Circle at 0x11dee0c50>,
#  <matplotlib.patches.Circle at 0x11dee2150>,
#  <matplotlib.patches.Circle at 0x11dee35c0>,
#  <matplotlib.patches.Circle at 0x11dee34d0>,
#  <matplotlib.patches.Circle at 0x11dee3fe0>,
#  <matplotlib.patches.Circle at 0x11dee32c0>,
#  <matplotlib.patches.Circle at 0x11dee3c20>,
#  <matplotlib.patches.Circle at 0x11dee36e0>,
#  <matplotlib.patches.Circle at 0x11dee0b60>,
#  <matplotlib.patches.Circle at 0x11dee1c10>,
#  <matplotlib.patches.Circle at 0x11dee1280>,
#  <matplotlib.patches.Circle at 0x11dee3d10>,
#  <matplotlib.patches.Circle at 0x11dee1bb0>,
#  <matplotlib.patches.Circle at 0x11dee13d0>,
#  <matplotlib.patches.Circle at 0x11dee2030>,
#  <matplotlib.patches.Circle at 0x11dee0650>,
#  <matplotlib.patches.Circle at 0x11dee0b90>,
#  <matplotlib.patches.Circle at 0x11dee1f70>,
#  <matplotlib.patches.Circle at 0x11dee0380>,
#  <matplotlib.patches.Circle at 0x11dee2cc0>,
#  <matplotlib.patches.Circle at 0x11dee06b0>,
#  <matplotlib.patches.Circle at 0x11dee3cb0>,
#  <matplotlib.patches.Circle at 0x11dee2c90>,
#  <matplotlib.patches.Circle at 0x11dee28d0>,
#  <matplotlib.patches.Circle at 0x11dee1eb0>,
#  <matplotlib.patches.Circle at 0x11dee3800>,
#  <matplotlib.patches.Circle at 0x11dee0440>,
#  <matplotlib.patches.Circle at 0x11dee0080>,
#  <matplotlib.patches.Circle at 0x11dee2cf0>,
#  <matplotlib.patches.Circle at 0x11dee1190>,
#  <matplotlib.patches.Circle at 0x11dee2ab0>,
#  <matplotlib.patches.Circle at 0x11dee31d0>,
#  <matplotlib.patches.Circle at 0x11dee12b0>,
#  <matplotlib.patches.Circle at 0x11dee07a0>,
#  <matplotlib.patches.Circle at 0x11dee1160>,
#  <matplotlib.patches.Circle at 0x11dee20c0>,
#  <matplotlib.patches.Circle at 0x11dee21b0>,
#  <matplotlib.patches.Circle at 0x11dee1a00>,
#  <matplotlib.patches.Circle at 0x11dee1070>,
#  <matplotlib.patches.Circle at 0x11dee2c30>,
#  <matplotlib.patches.Circle at 0x11dee0740>,
#  <matplotlib.patches.Circle at 0x11dee31a0>,
#  <matplotlib.patches.Circle at 0x11dee27e0>,
#  <matplotlib.patches.Circle at 0x11dee1940>,
#  <matplotlib.patches.Circle at 0x11dee3a70>,
#  <matplotlib.patches.Circle at 0x11dee2ae0>,
#  <matplotlib.patches.Circle at 0x11dee26c0>,
#  <matplotlib.patches.Circle at 0x11dee0d70>,
#  <matplotlib.patches.Circle at 0x11dee2750>,
#  <matplotlib.patches.Circle at 0x11dee1550>,
#  <matplotlib.patches.Circle at 0x11dee3020>,
#  <matplotlib.patches.Circle at 0x11dee05f0>,
#  <matplotlib.patches.Circle at 0x11dee3290>,
#  <matplotlib.patches.Circle at 0x11dee39e0>,
#  <matplotlib.patches.Circle at 0x11dee0770>,
#  <matplotlib.patches.Circle at 0x11dee38c0>,
#  <matplotlib.patches.Circle at 0x11dee24b0>,
#  <matplotlib.patches.Circle at 0x11dee2780>,
#  <matplotlib.patches.Circle at 0x11dee2360>,
#  <matplotlib.patches.Circle at 0x11dee3e30>,
#  <matplotlib.patches.Circle at 0x11dee34a0>,
#  <matplotlib.patches.Circle at 0x11de5e090>,
#  <matplotlib.patches.Circle at 0x11de5dd90>,
#  <matplotlib.patches.Circle at 0x11de5d9a0>,
#  <matplotlib.patches.Circle at 0x11de5d820>,
#  <matplotlib.patches.Circle at 0x11de5e8a0>,
#  <matplotlib.patches.Circle at 0x11de5c4d0>,
#  <matplotlib.patches.Circle at 0x11de5cc20>,
#  <matplotlib.patches.Circle at 0x11de5de80>,
#  <matplotlib.patches.Circle at 0x11de5fe60>,
#  <matplotlib.patches.Circle at 0x11de5d7f0>,
#  <matplotlib.patches.Circle at 0x11de5e150>,
#  <matplotlib.patches.Circle at 0x11de5ddc0>,
#  <matplotlib.patches.Circle at 0x11de5de20>,
#  <matplotlib.patches.Circle at 0x11de5e300>,
#  <matplotlib.patches.Circle at 0x11de5c290>,
#  <matplotlib.patches.Circle at 0x11de5cad0>,
#  <matplotlib.patches.Circle at 0x11de5f290>,
#  <matplotlib.patches.Circle at 0x11de5e900>,
#  <matplotlib.patches.Circle at 0x11de5cf20>,
#  <matplotlib.patches.Circle at 0x11de5d880>,
#  <matplotlib.patches.Circle at 0x11de5f560>,
#  <matplotlib.patches.Circle at 0x11de5c530>,
#  <matplotlib.patches.Circle at 0x11de5c6b0>,
#  <matplotlib.patches.Circle at 0x11de5f0b0>,
#  <matplotlib.patches.Circle at 0x11de5fce0>,
#  <matplotlib.patches.Circle at 0x11de5c770>,
#  <matplotlib.patches.Circle at 0x11de5c830>,
#  <matplotlib.patches.Circle at 0x11de5e180>,
#  <matplotlib.patches.Circle at 0x11de5c5f0>,
#  <matplotlib.patches.Circle at 0x11de5c1d0>,
#  <matplotlib.patches.Circle at 0x11de5c2c0>,
#  <matplotlib.patches.Circle at 0x11de5e0c0>,
#  <matplotlib.patches.Circle at 0x11de5e6c0>,
#  <matplotlib.patches.Circle at 0x11de5dca0>,
#  <matplotlib.patches.Circle at 0x11de5c7a0>,
#  <matplotlib.patches.Circle at 0x11de5f230>,
#  <matplotlib.patches.Circle at 0x11de5eab0>,
#  <matplotlib.patches.Circle at 0x11de5faa0>,
#  <matplotlib.patches.Circle at 0x11de5f9b0>,
#  <matplotlib.patches.Circle at 0x11de5cef0>,
#  <matplotlib.patches.Circle at 0x11de5e2a0>,
#  <matplotlib.patches.Circle at 0x11de5d400>,
#  <matplotlib.patches.Circle at 0x11de5da30>,
#  <matplotlib.patches.Circle at 0x11de5cb30>,
#  <matplotlib.patches.Circle at 0x11de5c920>,
#  <matplotlib.patches.Circle at 0x11de5ef60>,
#  <matplotlib.patches.Circle at 0x11de5e1b0>,
#  <matplotlib.patches.Circle at 0x11de5e3f0>,
#  <matplotlib.patches.Circle at 0x11de5d310>,
#  <matplotlib.patches.Circle at 0x11de5f4a0>,
#  <matplotlib.patches.Circle at 0x11de5f380>,
#  <matplotlib.patches.Circle at 0x11de5fd40>,
#  <matplotlib.patches.Circle at 0x11de5ddf0>,
#  <matplotlib.patches.Circle at 0x11de5d250>,
#  <matplotlib.patches.Circle at 0x11de5eba0>,
#  <matplotlib.patches.Circle at 0x11de5cfb0>,
#  <matplotlib.patches.Circle at 0x11de5cb90>,
#  <matplotlib.patches.Circle at 0x11de5efc0>,
#  <matplotlib.patches.Circle at 0x11de5db20>,
#  <matplotlib.patches.Circle at 0x11de5fa10>,
#  <matplotlib.patches.Circle at 0x11de5e7b0>,
#  <matplotlib.patches.Circle at 0x11de5fe00>,
#  <matplotlib.patches.Circle at 0x11de5c890>,
#  <matplotlib.patches.Circle at 0x11de5dfd0>,
#  <matplotlib.patches.Circle at 0x11de5ccb0>,
#  <matplotlib.patches.Circle at 0x11de5e540>,
#  <matplotlib.patches.Circle at 0x11de5cf80>,
#  <matplotlib.patches.Circle at 0x11de5fd70>,
#  <matplotlib.patches.Circle at 0x11de5fb60>,
#  <matplotlib.patches.Circle at 0x11de5f410>,
#  <matplotlib.patches.Circle at 0x11de5df10>,
#  <matplotlib.patches.Circle at 0x11de5e510>,
#  <matplotlib.patches.Circle at 0x11de5c9e0>,
#  <matplotlib.patches.Circle at 0x11de5f710>,
#  <matplotlib.patches.Circle at 0x11de5fa40>,
#  <matplotlib.patches.Circle at 0x11de5e870>,
#  <matplotlib.patches.Circle at 0x11de5d4f0>,
#  <matplotlib.patches.Circle at 0x11de5c620>,
#  <matplotlib.patches.Circle at 0x11de5e210>,
#  <matplotlib.patches.Circle at 0x11de5e930>,
#  <matplotlib.patches.Circle at 0x11de5cce0>,
#  <matplotlib.patches.Circle at 0x11de5e270>,
#  <matplotlib.patches.Circle at 0x11de5d610>,
#  <matplotlib.patches.Circle at 0x11de5ce90>,
#  <matplotlib.patches.Circle at 0x11de5ec60>,
#  <matplotlib.patches.Circle at 0x11de5cc50>,
#  <matplotlib.patches.Circle at 0x11de5d220>]

# %%
# HALT!!! 
# This OBVIOUSLY has the problem of over scan!!! Learn how to solve it once and for all right now!


# Finish Halt! I needed to perform overscann and trim. I did that today.
# Now next step is to perform all the above until the latest step this time with the data in the trim-raw folder 
# (meaning the overscanned and trimmed data)
