# %%
import numpy as np
from astropy.io import fits
from pathlib import Path
import os
import matplotlib.pyplot as plt
from convenience_functions import show_image

# %%
# If you need you can display the structure of the file
#fits.info(image_file)

# %%
# Specify the path of the image to be viewed:
image_file = os.path.join('C:\\Users\\Observatory\\Exo\\tut\\data\\sdss_g.fits' )

# %%
image_data = fits.getdata(image_file, ext=0)
output_filename = os.path.join(os.path.dirname(image_file), "output_image.png")
show_image(image_data, cmap='gray')

# The following line saves a copy of the image shown below in the same directory as the  
#plt.savefig(output_filename)

# %%
# And this is for plotting a histogram if needed:
histogram = plt.hist(image_data.flatten(), bins='auto')
#image_file.close()
